# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open("pipe.pkl", "rb"))

# %%
test_input2 = np.array([2, "male", 31.0, 0, 0, 10.5, "5"], dtype=object).reshape(1, 7)

# %%
pipe.predict(test_input2)
# Out:
# E:\Machine Learning\venv\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# E:\Machine Learning\venv\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
